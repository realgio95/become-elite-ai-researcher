# %% [markdown]
# # 5. Activation Functions
#
# Activation functions make neurons non-linear!
# Without them, neural networks would just be linear transformations.
# Let's explore different activation functions!

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
