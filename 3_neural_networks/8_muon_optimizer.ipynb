# %% [markdown]
# # 8. Muon Optimizer
#
# Muon is a newer optimizer that can outperform Adam!
# It's inspired by physics (muon particle) and uses exponential moving averages.
# Let's implement it from scratch!

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
